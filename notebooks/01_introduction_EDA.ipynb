# %%
import pandas as pd
import numpy as np
import sweetviz as sv

# %%
loan = pd.read_csv('data/Loan_test_set.csv')
# Out:
# C:\Users\RAMON\AppData\Local\Temp\ipykernel_17404\3961155555.py:1: DtypeWarning: Columns (0,1,2,3,4,7,13,19,24,25,27,28,29,30,31,32,33,34,36,38,39,40,41,42,43,44,45,46,48,51,52,53,54,55,57,58,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,132,133,137,138,140,141,142,148,149,150) have mixed types. Specify dtype option on import or set low_memory=False.
#   loan = pd.read_csv('data/Loan_test_set.csv')

# %%
loan.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# id        member_id loan_amnt funded_amnt funded_amnt_inv term       int_rate installment grade sub_grade emp_title        emp_length home_ownership annual_inc verification_status issue_d  loan_status pymnt_plan url                                                desc purpose            title                   zip_code addr_state dti   delinq_2yrs earliest_cr_line fico_range_low fico_range_high inq_last_6mths mths_since_last_delinq mths_since_last_record open_acc pub_rec revol_bal revol_util total_acc initial_list_status out_prncp out_prncp_inv total_pymnt total_pymnt_inv total_rec_prncp total_rec_int total_rec_late_fee recoveries collection_recovery_fee last_pymnt_d last_pymnt_amnt next_pymnt_d last_credit_pull_d last_fico_range_high last_fico_range_low collections_12_mths_ex_med mths_since_last_major_derog policy_code application_type annual_inc_joint dti_joint verification_status_joint acc_now_delinq tot_coll_amt tot_cur_bal open_acc_6m open_act_il open_il_12m open_il_24m mths_since_rcnt_il total_bal_il il_util open_rv_12m open_rv_24m max_bal_bc all_util total_rev_hi_lim inq_fi total_cu_tl inq_last_12m acc_open_past_24mths avg_cur_bal bc_open_to_buy bc_util chargeoff_within_12_mths delinq_amnt mo_sin_old_il_acct mo_sin_old_rev_tl_op mo_sin_rcnt_rev_tl_op mo_sin_rcnt_tl mort_acc mths_since_recent_bc mths_since_recent_bc_dlq mths_since_recent_inq mths_since_recent_revol_delinq num_accts_ever_120_pd num_actv_bc_tl num_actv_rev_tl num_bc_sats num_bc_tl num_il_tl num_op_rev_tl num_rev_accts num_rev_tl_bal_gt_0 num_sats num_tl_120dpd_2m num_tl_30dpd num_tl_90g_dpd_24m num_tl_op_past_12m pct_tl_nvr_dlq percent_bc_gt_75 pub_rec_bankruptcies tax_liens tot_hi_cred_lim total_bal_ex_mort total_bc_limit total_il_high_credit_limit revol_bal_joint sec_app_fico_range_low sec_app_fico_range_high sec_app_earliest_cr_line sec_app_inq_last_6mths sec_app_mort_acc sec_app_open_acc sec_app_revol_util sec_app_open_act_il sec_app_num_rev_accts sec_app_chargeoff_within_12_mths sec_app_collections_12_mths_ex_med sec_app_mths_since_last_major_derog hardship_flag hardship_type hardship_reason hardship_status deferral_term hardship_amount hardship_start_date hardship_end_date payment_plan_start_date hardship_length hardship_dpd hardship_loan_status orig_projected_additional_accrued_interest hardship_payoff_balance_amount hardship_last_payment_amount disbursement_method debt_settlement_flag debt_settlement_flag_date settlement_status settlement_date settlement_amount settlement_percentage                                    settlement_term
# 104046719 NaN       14000     14000       14000            36 months  15.99%  492.13      C     C5        Project Leader   10+ years  MORTGAGE       82000      Source Verified     Mar-2017 Current     n          https://lendingclub.com/browse/loanDetail.actio... NaN  credit_card        Credit card refinancing 672xx    KS         31.07 0           May-1996         725            729             0              NaN                    NaN                    18       0       69578     63.2%      31        w                   11438.26  11438.26      3912.17     3912.17         2561.74         1350.43       0.0                0.0        0.0                     Dec-2017     492.13          Jan-2018     Dec-2017           714                  710                 0                          NaN                         1           Individual       NaN              NaN       NaN                       0              0            202617      0           3           0           1           22                 34430        57      0           2           13686      61       110037           0      9           0            3                    11257       29762          63.4    0                        0           140                250                  13                    13             6        13                   NaN                      13                    NaN                            0                     7              9               8           13        4         14            21            9                   18       0                0            0                  0                  100            25               0                    0         286204          104008            81400          60167                      NaN             NaN                    NaN                     NaN                      NaN                    NaN              NaN              NaN                NaN                 NaN                   NaN                              NaN                                NaN                                 N             NaN           NaN             NaN             NaN           NaN             NaN                 NaN               NaN                     NaN             NaN          NaN                  NaN                                        NaN                            NaN                          Cash                N                    NaN                       NaN               NaN             NaN               NaN                                                                  NaN
# 104048967 NaN       5000      5000        5000             36 months  25.49%  200.1       E     E4        Pilot            10+ years  MORTGAGE       215000     Source Verified     Mar-2017 Current     n          https://lendingclub.com/browse/loanDetail.actio... NaN  debt_consolidation Debt consolidation      067xx    CT         6.06  0           Jan-2004         765            769             4              NaN                    NaN                    11       0       8678      18.8%      16        f                   4190.59   4190.59       1586.64     1586.64         809.41          777.23        0.0                0.0        0.0                     Dec-2017     200.1           Jan-2018     Dec-2017           779                  775                 0                          NaN                         1           Individual       NaN              NaN       NaN                       0              0            44754       1           3           2           4           7                  35832        68      2           2           8659       27       46200            2      0           6            6                    4069        37522          18.8    0                        0           83                 87                   5                     5              0        5                    NaN                      0                     NaN                            0                     2              2               7           8         7         7             8             2                   11       0                0            0                  4                  100            0                0                    0         100763          44754             46200          49814                      NaN             NaN                    NaN                     NaN                      NaN                    NaN              NaN              NaN                NaN                 NaN                   NaN                              NaN                                NaN                                 N             NaN           NaN             NaN             NaN           NaN             NaN                 NaN               NaN                     NaN             NaN          NaN                  NaN                                        NaN                            NaN                          Cash                N                    NaN                       NaN               NaN             NaN               NaN                                                                  NaN
# 104028593 NaN       4600      4600        4600             36 months  11.39%  151.45      B     B3        cable technician 4 years    RENT           44470      Not Verified        Mar-2017 Current     n          https://lendingclub.com/browse/loanDetail.actio... NaN  credit_card        Credit card refinancing 066xx    CT         13.43 0           Dec-2003         770            774             1              NaN                    NaN                    7        0       5400      19.1%      11        w                   3708.50   3708.50       1205.78     1205.78         891.50          314.28        0.0                0.0        0.0                     Dec-2017     151.45          Jan-2018     Dec-2017           769                  765                 0                          NaN                         1           Individual       NaN              NaN       NaN                       0              0            9625        1           1           0           1           22                 4225         36      2           4           4670       24       28300            0      0           1            5                    1375        9610           33.7    0                        0           77                 159                  1                     1              0        7                    NaN                      1                     NaN                            0                     2              3               3           4         2         6             9             3                   7        0                0            0                  2                  100            0                0                    0         40000           9625              14500          11700                      NaN             NaN                    NaN                     NaN                      NaN                    NaN              NaN              NaN                NaN                 NaN                   NaN                              NaN                                NaN                                 N             NaN           NaN             NaN             NaN           NaN             NaN                 NaN               NaN                     NaN             NaN          NaN                  NaN                                        NaN                            NaN                          Cash                N                    NaN                       NaN               NaN             NaN               NaN                                                                  NaN
# 104046702 NaN       14000     14000       14000            60 months  12.74%  316.69      C     C1        Specialty Sales  4 years    OWN            40000      Not Verified        Mar-2017 Current     n          https://lendingclub.com/browse/loanDetail.actio... NaN  credit_card        Credit card refinancing 926xx    CA         17.48 0           Feb-1974         715            719             0              NaN                    NaN                    10       0       25787     46.2%      23        w                   12604.51  12604.51      2585.32     2585.32         1395.49         1189.83       0.0                0.0        0.0                     Dec-2017     316.69          Jan-2018     Dec-2017           714                  710                 0                          NaN                         1           Individual       NaN              NaN       NaN                       0              0            25787       2           0           0           0           129                0            NaN     5           7           8549       46       55800            0      3           0            7                    2579        27153          48.3    0                        0           129                517                  1                     1              1        2                    NaN                      23                    NaN                            0                     7              9               8           13        1         10            21            9                   10       0                0            0                  5                  100            37.5             0                    0         55800           25787             52500          0                          NaN             NaN                    NaN                     NaN                      NaN                    NaN              NaN              NaN                NaN                 NaN                   NaN                              NaN                                NaN                                 N             NaN           NaN             NaN             NaN           NaN             NaN                 NaN               NaN                     NaN             NaN          NaN                  NaN                                        NaN                            NaN                          Cash                N                    NaN                       NaN               NaN             NaN               NaN                                                                  NaN

# %%
loan.tail()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# 94477589                                         NaN 10000 10000 10000  36 months   8.24% 314.48 B   B1  NaN                        NaN    MORTGAGE 46203.0 Not Verified    Jan-2017 Current n   https://lendingclub.com/browse/loanDetail.actio... NaN debt_consolidation Debt consolidation 342xx FL  17.04 0   Nov-2002 670 674 0   38.0 NaN  8   0   7315  51.2% 15  f   7201.28 7201.28 3450.12 3450.12 2798.72 651.4   0.0 0.0 0.0 Dec-2017 314.48 Jan-2018 Dec-2017 669 665 0   NaN  1   Individual NaN NaN NaN 0   0    252054.0 0   1   0   1   18.0 17437.0 80.0 0   0   4280 68.0 14300 0   1   0   1   36008.0 5485.0 57.1 0   0   113.0 169 25  18  1   25.0 38.0 NaN  38.0 0   3   3   4   6   5   6   9   3   8   0.0 0   0   0   86.7  25.0 0   0   263677.0 24752 12800 21877 NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN N   NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN Cash N   NaN NaN NaN NaN NaN                                                NaN
# 94048859                                         NaN 6325  6325  6325   36 months  15.99% 222.34 C   C5  NaN                        NaN    OWN      24564.0 Not Verified    Jan-2017 Current n   https://lendingclub.com/browse/loanDetail.actio... NaN debt_consolidation Debt consolidation 183xx PA  21.38 2   Oct-1986 705 709 0   15.0 NaN  12  0   1928  9.4%  17  w   4701.01 4701.01 2473.1  2473.1  1623.99 849.11  0.0 0.0 0.0 Dec-2017 222.34 Jan-2018 Dec-2017 644 640 0   25.0 1   Individual NaN NaN NaN 0   1465 8046     2   1   1   1   11.0 6118    82.0 3   3   989  29.0 20600 0   0   0   4   731     9211.0 15.5 0   0   141.0 362 1   1   0   6.0  15.0 NaN  15.0 0   4   6   4   8   2   11  15  6   12  0.0 0   0   4   82.4  0.0  0   0   28025    8046  10900 7425  NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN N   NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN Cash N   NaN NaN NaN NaN NaN                                                NaN
# 94038849                                         NaN 15625 15625 15625  60 months  28.69% 493.03 F   F1  Certified Dietary Manager  1 year RENT     34000.0 Source Verified Jan-2017 Current n   https://lendingclub.com/browse/loanDetail.actio... NaN debt_consolidation Debt consolidation 834xx ID  32.4  0   Apr-2005 690 694 0   68.0 52.0 13  1   18259 51.7% 18  f   14142.0 14142.0 5546.52 5546.52 1483.0  4063.52 0.0 0.0 0.0 Dec-2017 641.12 Jan-2018 Dec-2017 699 695 0   68.0 1   Individual NaN NaN NaN 0   0    27074.0  0   1   0   1   24.0 8815    59.0 0   3   6478 54.0 35300 0   0   0   4   2256    6690.0 70.0 0   0   140.0 114 16  16  0   16.0 NaN  17.0 NaN  1   4   7   5   6   5   12  13  7   13  0.0 0   0   0   100.0 40.0 0   1   50269.0  27074 22300 14969 NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN N   NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN Cash N   NaN NaN NaN NaN NaN                                                NaN
# Total amount funded in policy code 1: 1437969475 NaN NaN   NaN   NaN   NaN        NaN     NaN    NaN NaN NaN                        NaN    NaN      NaN     NaN             NaN      NaN     NaN NaN                                                NaN NaN                NaN                NaN   NaN NaN   NaN NaN      NaN NaN NaN NaN  NaN  NaN NaN NaN   NaN   NaN NaN NaN     NaN     NaN     NaN     NaN     NaN     NaN NaN NaN NaN      NaN    NaN      NaN      NaN NaN NaN NaN  NaN NaN        NaN NaN NaN NaN NaN  NaN      NaN NaN NaN NaN NaN  NaN     NaN  NaN NaN NaN  NaN  NaN   NaN NaN NaN NaN NaN     NaN    NaN  NaN NaN NaN   NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN   NaN  NaN NaN NaN      NaN   NaN   NaN   NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  NaN NaN NaN NaN NaN NaN                                                NaN
# Total amount funded in policy code 2: 520780182  NaN NaN   NaN   NaN   NaN        NaN     NaN    NaN NaN NaN                        NaN    NaN      NaN     NaN             NaN      NaN     NaN NaN                                                NaN NaN                NaN                NaN   NaN NaN   NaN NaN      NaN NaN NaN NaN  NaN  NaN NaN NaN   NaN   NaN NaN NaN     NaN     NaN     NaN     NaN     NaN     NaN NaN NaN NaN      NaN    NaN      NaN      NaN NaN NaN NaN  NaN NaN        NaN NaN NaN NaN NaN  NaN      NaN NaN NaN NaN NaN  NaN     NaN  NaN NaN NaN  NaN  NaN   NaN NaN NaN NaN NaN     NaN    NaN  NaN NaN NaN   NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN   NaN  NaN NaN NaN      NaN   NaN   NaN   NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  NaN NaN NaN NaN NaN NaN                                                NaN

# %%
report = sv.analyze(loan)
report.show_notebook()
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 report = sv.analyze(loan)
#       2 report.show_notebook()
#
# File ~\miniconda3\envs\practica0\lib\site-packages\sweetviz\sv_public.py:12, in analyze(source, target_feat, feat_cfg, pairwise_analysis)
#       8 def analyze(source: Union[pd.DataFrame, Tuple[pd.DataFrame, str]],
#       9             target_feat: str = None,
#      10             feat_cfg: FeatureConfig = None,
#      11             pairwise_analysis: str = 'auto'):
# ---> 12     report = sweetviz.DataframeReport(source, target_feat, None,
#      13                                       pairwise_analysis, feat_cfg)
#      14     return report
#
# File ~\miniconda3\envs\practica0\lib\site-packages\sweetviz\dataframe_report.py:277, in DataframeReport.__init__(self, source, target_feature_name, compare, pairwise_analysis, fc, verbosity)
#     274 for f in features_to_process:
#     275     # start = time.perf_counter()
#     276     self.progress_bar.set_description_str(f"Feature: {f.source.name}")
# --> 277     self._features[f.source.name] = sa.analyze_feature_to_dictionary(f)
#     278     self.progress_bar.update(1)
#     279     # print(f"DONE FEATURE------> {f.source.name}"
#     280     #       f" {(time.perf_counter() - start):.2f}   {self._features[f.source.name]['type']}")
#     281 # self.progress_bar.set_description_str('[FEATURES DONE]')
#     282 # self.progress_bar.close()
#     283
#     284 # Wrap up summary
#
# File ~\miniconda3\envs\practica0\lib\site-packages\sweetviz\series_analyzer.py:99, in analyze_feature_to_dictionary(to_process)
#      97 # Determine SOURCE feature type
#      98 to_process.source_counts = get_counts(to_process.source)
# ---> 99 returned_feature_dict["type"] = determine_feature_type(to_process.source, to_process.source_counts,
#     100                                                        to_process.predetermined_type, "SOURCE")
#     101 source_type = returned_feature_dict["type"]
#     103 # Determine COMPARED feature type & initialize
#
# File ~\miniconda3\envs\practica0\lib\site-packages\sweetviz\type_detection.py:13, in determine_feature_type(series, counts, must_be_this_type, which_dataframe)
#       6 def determine_feature_type(series: pd.Series, counts: dict,
#       7         must_be_this_type: FeatureType, which_dataframe: str) -> object:
#       8     # Replace infinite values with NaNs to avoid issues with histograms
#       9     # TODO: INFINITE VALUE HANDLING/WARNING
#      10     # series.replace(to_replace=[np.inf, np.NINF, np.PINF], value=np.nan,
#      11     #                inplace=True)
#      12     if counts["value_counts_without_nan"].index.inferred_type.startswith("mixed"):
# ---> 13         raise TypeError(f"\n\nColumn [{series.name}] has a 'mixed' inferred_type (as determined by Pandas).\n"
#      14                         f"This is is not currently supported; column types should not contain mixed data.\n"
#      15                         f"e.g. only floats or strings, but not a combination.\n\n"
#      16                         f"POSSIBLE RESOLUTIONS:\n"
#      17                         f"BEST -> Make sure series [{series.name}] only contains a certain type of data (numerical OR string).\n"
#      18                         f"OR -> Convert series [{series.name}] to a string (if makes sense) so it will be picked up as CATEGORICAL or TEXT.\n"
#      19                         f"     One way to do this is:\n"
#      20                         f"     df['{series.name}'] = df['{series.name}'].astype(str)\n"
#      21                         f"OR -> Convert series [{series.name}] to a numerical value (if makes sense):\n"
#      22                         f"     One way to do this is:\n"
#      23                         f"     df['{series.name}'] = pd.to_numeric(df['{series.name}'], errors='coerce')\n"
#      24                         f"     # (errors='coerce' will transform string values to NaN, that can then be replaced if desired;"
#      25                         f" consult Pandas manual pages for more details)\n"
#      26                         )
#      28     try:
#      29         # TODO: must_be_this_type ENFORCING
#      30         if counts["distinct_count_without_nan"] == 0:
#      31             # Empty
#
# TypeError:
#
# Column [Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)] has a 'mixed' inferred_type (as determined by Pandas).
# This is is not currently supported; column types should not contain mixed data.
# e.g. only floats or strings, but not a combination.
#
# POSSIBLE RESOLUTIONS:
# BEST -> Make sure series [Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)] only contains a certain type of data (numerical OR string).
# OR -> Convert series [Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)] to a string (if makes sense) so it will be picked up as CATEGORICAL or TEXT.
#      One way to do this is:
#      df['Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)'] = df['Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)'].astype(str)
# OR -> Convert series [Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)] to a numerical value (if makes sense):
#      One way to do this is:
#      df['Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)'] = pd.to_numeric(df['Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)'], errors='coerce')
#      # (errors='coerce' will transform string values to NaN, that can then be replaced if desired; consult Pandas manual pages for more details)

# %%
# !pip install dtale 
import dtale 
from dtale.views import startup

import dtale.app as dtale_app 

dtale_app.USE_COLAB = True

dtale.show(loan)
# Out:
# Collecting dtale
#   Downloading dtale-3.14.1-py2.py3-none-any.whl.metadata (17 kB)
# Collecting dash-colorscales (from dtale)
#   Downloading dash_colorscales-0.0.4.tar.gz (62 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting dash-daq (from dtale)
#   Downloading dash_daq-0.5.0.tar.gz (642 kB)
#      ---------------------------------------- 0.0/642.7 kB ? eta -:--:--
#      ------------------------------------- 642.7/642.7 kB 11.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting Flask-Compress (from dtale)
#   Downloading Flask_Compress-1.17-py3-none-any.whl.metadata (8.8 kB)
# Collecting future>=0.14.0 (from dtale)
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting kaleido (from dtale)
#   Downloading kaleido-0.2.1-py2.py3-none-win_amd64.whl.metadata (15 kB)
# Collecting missingno (from dtale)
#   Downloading missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: pandas in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from dtale) (2.2.3)
# Collecting squarify (from dtale)
#   Downloading squarify-0.4.4-py3-none-any.whl.metadata (600 bytes)
# Collecting strsimpy (from dtale)
#   Downloading strsimpy-0.2.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: six in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from dtale) (1.16.0)
# Collecting xlrd (from dtale)
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: beautifulsoup4!=4.13.0b2 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from dtale) (4.12.3)
# Requirement already satisfied: certifi in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from dtale) (2024.8.30)
# Collecting flask-ngrok (from dtale)
#   Downloading flask_ngrok-0.0.25-py3-none-any.whl.metadata (1.8 kB)
# Collecting lz4 (from dtale)
#   Downloading lz4-4.3.3-cp310-cp310-win_amd64.whl.metadata (3.8 kB)
# Requirement already satisfied: cycler in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from dtale) (0.12.1)
# Collecting dash-bootstrap-components<=1.3.1 (from dtale)
#   Downloading dash_bootstrap_components-1.3.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting dash (from dtale)
#   Downloading dash-2.18.1-py3-none-any.whl.metadata (10 kB)
# Collecting seaborn (from dtale)
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting werkzeug (from dtale)
#   Downloading werkzeug-3.0.4-py3-none-any.whl.metadata (3.7 kB)
# Collecting scikit-learn (from dtale)
#   Downloading scikit_learn-1.5.2-cp310-cp310-win_amd64.whl.metadata (13 kB)
# Collecting statsmodels (from dtale)
#   Downloading statsmodels-0.14.4-cp310-cp310-win_amd64.whl.metadata (9.5 kB)
# Collecting networkx (from dtale)
#   Downloading networkx-3.4.1-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from dtale) (2.1.2)
# Collecting openpyxl!=3.2.0b1 (from dtale)
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting xarray (from dtale)
#   Downloading xarray-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: scipy!=1.12.0rc1,!=1.14.0,!=1.14.0rc1,!=1.14.0rc2 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from dtale) (1.14.1)
# Collecting et-xmlfile (from dtale)
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting plotly (from dtale)
#   Downloading plotly-5.24.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting Flask<2.3 (from dtale)
#   Downloading Flask-2.2.5-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: requests in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from dtale) (2.32.3)
# Collecting itsdangerous (from dtale)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: contourpy in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from dtale) (1.3.0)
# Requirement already satisfied: matplotlib in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from dtale) (3.9.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from beautifulsoup4!=4.13.0b2->dtale) (2.5)
# Collecting dash-html-components==2.0.0 (from dash->dtale)
#   Downloading dash_html_components-2.0.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting dash-core-components==2.0.0 (from dash->dtale)
#   Downloading dash_core_components-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting dash-table==5.0.0 (from dash->dtale)
#   Downloading dash_table-5.0.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: importlib-metadata in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from dash->dtale) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from dash->dtale) (4.12.2)
# Collecting retrying (from dash->dtale)
#   Downloading retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: nest-asyncio in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from dash->dtale) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from dash->dtale) (75.1.0)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from Flask<2.3->dtale) (3.1.4)
# Collecting click>=8.0 (from Flask<2.3->dtale)
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting tenacity>=6.2.0 (from plotly->dtale)
#   Downloading tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: packaging in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from plotly->dtale) (24.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from werkzeug->dtale) (3.0.1)
# Requirement already satisfied: brotli in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from Flask-Compress->dtale) (1.1.0)
# Requirement already satisfied: zstandard in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from Flask-Compress->dtale) (0.23.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from matplotlib->dtale) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from matplotlib->dtale) (1.4.7)
# Requirement already satisfied: pillow>=8 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from matplotlib->dtale) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from matplotlib->dtale) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from matplotlib->dtale) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from pandas->dtale) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from pandas->dtale) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from requests->dtale) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from requests->dtale) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from requests->dtale) (2.2.3)
# Collecting joblib>=1.2.0 (from scikit-learn->dtale)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->dtale)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting patsy>=0.5.6 (from statsmodels->dtale)
#   Downloading patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: colorama in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from click>=8.0->Flask<2.3->dtale) (0.4.6)
# Requirement already satisfied: zipp>=3.20 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from importlib-metadata->dash->dtale) (3.20.2)
# Downloading dtale-3.14.1-py2.py3-none-any.whl (14.5 MB)
#    ---------------------------------------- 0.0/14.5 MB ? eta -:--:--
#    --------------- ------------------------ 5.8/14.5 MB 32.0 MB/s eta 0:00:01
#    ---------------------------------------- 14.5/14.5 MB 37.9 MB/s eta 0:00:00
# Downloading dash_bootstrap_components-1.3.1-py3-none-any.whl (219 kB)
# Downloading dash-2.18.1-py3-none-any.whl (7.5 MB)
#    ---------------------------------------- 0.0/7.5 MB ? eta -:--:--
#    ---------------------------------------- 7.5/7.5 MB 51.3 MB/s eta 0:00:00
# Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Downloading Flask-2.2.5-py3-none-any.whl (101 kB)
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading plotly-5.24.1-py3-none-any.whl (19.1 MB)
#    ---------------------------------------- 0.0/19.1 MB ? eta -:--:--
#    --------------- ------------------------ 7.3/19.1 MB 64.3 MB/s eta 0:00:01
#    -------------------------------- ------- 15.5/19.1 MB 38.9 MB/s eta 0:00:01
#    ---------------------------------------- 19.1/19.1 MB 37.6 MB/s eta 0:00:00
# Downloading werkzeug-3.0.4-py3-none-any.whl (227 kB)
# Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Downloading Flask_Compress-1.17-py3-none-any.whl (8.7 kB)
# Downloading flask_ngrok-0.0.25-py3-none-any.whl (3.1 kB)
# Downloading kaleido-0.2.1-py2.py3-none-win_amd64.whl (65.9 MB)
#    ---------------------------------------- 0.0/65.9 MB ? eta -:--:--
#    ------- -------------------------------- 13.1/65.9 MB 63.3 MB/s eta 0:00:01
#    -------------- ------------------------- 24.4/65.9 MB 59.4 MB/s eta 0:00:01
#    -------------------- ------------------- 34.6/65.9 MB 54.9 MB/s eta 0:00:01
#    -------------------------- ------------- 43.0/65.9 MB 51.6 MB/s eta 0:00:01
#    ------------------------------- -------- 52.7/65.9 MB 50.1 MB/s eta 0:00:01
#    ------------------------------------- -- 61.9/65.9 MB 49.3 MB/s eta 0:00:01
#    ---------------------------------------- 65.9/65.9 MB 46.2 MB/s eta 0:00:00
# Downloading lz4-4.3.3-cp310-cp310-win_amd64.whl (99 kB)
# Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Downloading networkx-3.4.1-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 47.1 MB/s eta 0:00:00
# Downloading scikit_learn-1.5.2-cp310-cp310-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    -------------------------------- ------- 8.9/11.0 MB 42.4 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 40.4 MB/s eta 0:00:00
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading squarify-0.4.4-py3-none-any.whl (4.1 kB)
# Downloading statsmodels-0.14.4-cp310-cp310-win_amd64.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ------------------------------- -------- 7.9/9.8 MB 40.7 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 32.3 MB/s eta 0:00:00
# Downloading strsimpy-0.2.1-py3-none-any.whl (45 kB)
# Downloading xarray-2024.9.0-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 15.0 MB/s eta 0:00:00
# Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
# Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Building wheels for collected packages: dash-colorscales, dash-daq
#   Building wheel for dash-colorscales (setup.py): started
#   Building wheel for dash-colorscales (setup.py): finished with status 'done'
#   Created wheel for dash-colorscales: filename=dash_colorscales-0.0.4-py3-none-any.whl size=62571 sha256=bbceb24a25e65483a7743e120ea977da49485ea712817d1bc099b52bcc16cb85
#   Stored in directory: c:\users\ramon\appdata\local\pip\cache\wheels\70\6a\1f\95b2135cd2c895f0cd8b5d6d6ae7d5ed0a883580b34a31a14d
#   Building wheel for dash-daq (setup.py): started
#   Building wheel for dash-daq (setup.py): finished with status 'done'
#   Created wheel for dash-daq: filename=dash_daq-0.5.0-py3-none-any.whl size=669717 sha256=7efacd1580dd7f236efeb0a9f3103b7bf741d039875afb07490eb459aa4d2e4a
#   Stored in directory: c:\users\ramon\appdata\local\pip\cache\wheels\75\14\1b\208d09d5e239391048bdc167759977b41ba65a3d4063aebf6b
# Successfully built dash-colorscales dash-daq
# Installing collected packages: strsimpy, squarify, kaleido, dash-table, dash-html-components, dash-core-components, dash-colorscales, xlrd, werkzeug, threadpoolctl, tenacity, retrying, patsy, networkx, lz4, joblib, itsdangerous, future, et-xmlfile, click, scikit-learn, plotly, openpyxl, Flask, xarray, statsmodels, seaborn, flask-ngrok, Flask-Compress, dash, missingno, dash-daq, dash-bootstrap-components, dtale
# Successfully installed Flask-2.2.5 Flask-Compress-1.17 click-8.1.7 dash-2.18.1 dash-bootstrap-components-1.3.1 dash-colorscales-0.0.4 dash-core-components-2.0.0 dash-daq-0.5.0 dash-html-components-2.0.0 dash-table-5.0.0 dtale-3.14.1 et-xmlfile-1.1.0 flask-ngrok-0.0.25 future-1.0.0 itsdangerous-2.2.0 joblib-1.4.2 kaleido-0.2.1 lz4-4.3.3 missingno-0.5.2 networkx-3.4.1 openpyxl-3.1.5 patsy-0.5.6 plotly-5.24.1 retrying-1.3.4 scikit-learn-1.5.2 seaborn-0.13.2 squarify-0.4.4 statsmodels-0.14.4 strsimpy-0.2.1 tenacity-9.0.0 threadpoolctl-3.5.0 werkzeug-3.0.4 xarray-2024.9.0 xlrd-2.0.1
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\RAMON\miniconda3\envs\practica0\lib\site-packages\dtale\utils.py:865: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 9
#       5 import dtale.app as dtale_app
#       7 dtale_app.USE_COLAB = True
# ----> 9 dtale.show(loan)
#
# File ~\miniconda3\envs\practica0\lib\site-packages\dtale\app.py:792, in show(data, data_loader, name, context_vars, **options)
#     788 app_url = build_url(ACTIVE_PORT, ACTIVE_HOST)
#     789 startup_url, final_app_root = build_startup_url_and_app_root(
#     790     final_options["app_root"]
#     791 )
# --> 792 instance = startup(
#     793     startup_url,
#     794     data=data,
#     795     data_loader=data_loader,
#     796     name=name,
#     797     context_vars=context_vars,
#     798     ignore_duplicate=final_options["ignore_duplicate"],
#     799     allow_cell_edits=final_options["allow_cell_edits"],
#     800     inplace=final_options["inplace"],
#     801     drop_index=final_options["drop_index"],
#     802     precision=final_options["precision"],
#     803     show_columns=final_options["show_columns"],
#     804     hide_columns=final_options["hide_columns"],
#     805     column_formats=final_options["column_formats"],
#     806     nan_display=final_options["nan_display"],
#     807     sort=final_options["sort"],
#     808     locked=final_options["locked"],
#     809     background_mode=final_options["background_mode"],
#     810     range_highlights=final_options["range_highlights"],
#     811     vertical_headers=final_options["vertical_headers"],
#     812     is_proxy=JUPYTER_SERVER_PROXY,
#     813     app_root=final_app_root,
#     814     hide_shutdown=final_options.get("hide_shutdown"),
#     815     column_edit_options=final_options.get("column_edit_options"),
#     816     auto_hide_empty_columns=final_options.get("auto_hide_empty_columns"),
#     817     highlight_filter=final_options.get("highlight_filter"),
#     818     hide_header_editor=final_options.get("hide_header_editor"),
#     819     lock_header_menu=final_options.get("lock_header_menu"),
#     820     hide_header_menu=final_options.get("hide_header_menu"),
#     821     hide_main_menu=final_options.get("hide_main_menu"),
#     822     hide_column_menus=final_options.get("hide_column_menus"),
#     823     enable_custom_filters=final_options.get("enable_custom_filters"),
#     824     enable_web_uploads=final_options.get("enable_web_uploads"),
#     825     main_title=final_options.get("main_title"),
#     826     main_title_font=final_options.get("main_title_font"),
#     827 )
#     828 instance.started_with_open_browser = final_options["open_browser"]
#     829 is_active = not running_with_flask_debug() and is_up(app_url)
#
# File ~\miniconda3\envs\practica0\lib\site-packages\dtale\views.py:1234, in startup(url, data, data_loader, name, data_id, context_vars, ignore_duplicate, allow_cell_edits, inplace, drop_index, precision, show_columns, hide_columns, optimize_dataframe, column_formats, nan_display, sort, locked, background_mode, range_highlights, app_root, is_proxy, vertical_headers, hide_shutdown, column_edit_options, auto_hide_empty_columns, highlight_filter, hide_header_editor, lock_header_menu, hide_header_menu, hide_main_menu, hide_column_menus, enable_custom_filters, enable_web_uploads, force_save, main_title, main_title_font)
#    1230     data = optimize_df(data)
#    1231 if force_save or (
#    1232     global_state.is_arcticdb and not global_state.contains(data_id)
#    1233 ):
# -> 1234     data = data[curr_locked + [c for c in data.columns if c not in curr_locked]]
#    1235     global_state.set_data(data_id, data)
#    1236 dtypes_data = data
#
# File ~\miniconda3\envs\practica0\lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\miniconda3\envs\practica0\lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~\miniconda3\envs\practica0\lib\site-packages\pandas\core\indexes\base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['index'] not in index"

# %%
# !pip install pandas-profiling
import pandas as pd
from pandas_profiling import ProfileReport

profile = ProfileReport(loan, title='Informe de Análisis Exploratorio de Datos', explorative=True)
profile.to_widgets()
# Out:
# Collecting pandas-profiling
#   Downloading pandas_profiling-3.6.6-py2.py3-none-any.whl.metadata (4.5 kB)
# Collecting ydata-profiling (from pandas-profiling)
#   Downloading ydata_profiling-4.11.0-py2.py3-none-any.whl.metadata (20 kB)
# Collecting scipy<1.14,>=1.4.1 (from ydata-profiling->pandas-profiling)
#   Downloading scipy-1.13.1-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: pandas!=1.4.0,<3,>1.1 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from ydata-profiling->pandas-profiling) (2.2.3)
# Requirement already satisfied: matplotlib<3.10,>=3.5 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from ydata-profiling->pandas-profiling) (3.9.2)
# Collecting pydantic>=2 (from ydata-profiling->pandas-profiling)
#   Downloading pydantic-2.9.2-py3-none-any.whl.metadata (149 kB)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from ydata-profiling->pandas-profiling) (6.0.2)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from ydata-profiling->pandas-profiling) (3.1.4)
# Collecting visions<0.7.7,>=0.7.5 (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling->pandas-profiling)
#   Downloading visions-0.7.6-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from ydata-profiling->pandas-profiling) (2.1.2)
# Collecting htmlmin==0.1.12 (from ydata-profiling->pandas-profiling)
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting phik<0.13,>=0.11.1 (from ydata-profiling->pandas-profiling)
#   Downloading phik-0.12.4-cp310-cp310-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: requests<3,>=2.24.0 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from ydata-profiling->pandas-profiling) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.48.2 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from ydata-profiling->pandas-profiling) (4.66.5)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from ydata-profiling->pandas-profiling) (0.13.2)
# Collecting multimethod<2,>=1.4 (from ydata-profiling->pandas-profiling)
#   Downloading multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from ydata-profiling->pandas-profiling) (0.14.4)
# Collecting typeguard<5,>=3 (from ydata-profiling->pandas-profiling)
#   Downloading typeguard-4.3.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting imagehash==4.3.1 (from ydata-profiling->pandas-profiling)
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting wordcloud>=1.9.3 (from ydata-profiling->pandas-profiling)
#   Downloading wordcloud-1.9.3-cp310-cp310-win_amd64.whl.metadata (3.5 kB)
# Collecting dacite>=1.8 (from ydata-profiling->pandas-profiling)
#   Downloading dacite-1.8.1-py3-none-any.whl.metadata (15 kB)
# Collecting numba<1,>=0.56.0 (from ydata-profiling->pandas-profiling)
#   Downloading numba-0.60.0-cp310-cp310-win_amd64.whl.metadata (2.8 kB)
# Collecting PyWavelets (from imagehash==4.3.1->ydata-profiling->pandas-profiling)
#   Downloading pywavelets-1.7.0-cp310-cp310-win_amd64.whl.metadata (9.0 kB)
# Requirement already satisfied: pillow in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from imagehash==4.3.1->ydata-profiling->pandas-profiling) (10.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling->pandas-profiling) (3.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling->pandas-profiling) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling->pandas-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling->pandas-profiling) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling->pandas-profiling) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling->pandas-profiling) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling->pandas-profiling) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling->pandas-profiling) (2.9.0)
# Collecting llvmlite<0.44,>=0.43.0dev0 (from numba<1,>=0.56.0->ydata-profiling->pandas-profiling)
#   Downloading llvmlite-0.43.0-cp310-cp310-win_amd64.whl.metadata (4.9 kB)
# Collecting numpy<2.2,>=1.16.0 (from ydata-profiling->pandas-profiling)
#   Downloading numpy-2.0.2-cp310-cp310-win_amd64.whl.metadata (59 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling->pandas-profiling) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling->pandas-profiling) (2024.2)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from phik<0.13,>=0.11.1->ydata-profiling->pandas-profiling) (1.4.2)
# Collecting annotated-types>=0.6.0 (from pydantic>=2->ydata-profiling->pandas-profiling)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.23.4 (from pydantic>=2->ydata-profiling->pandas-profiling)
#   Downloading pydantic_core-2.23.4-cp310-none-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from pydantic>=2->ydata-profiling->pandas-profiling) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (2024.8.30)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling->pandas-profiling) (0.5.6)
# Requirement already satisfied: colorama in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from tqdm<5,>=4.48.2->ydata-profiling->pandas-profiling) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling->pandas-profiling) (24.2.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling->pandas-profiling) (3.4.1)
# Requirement already satisfied: six in c:\users\ramon\miniconda3\envs\practica0\lib\site-packages (from patsy>=0.5.6->statsmodels<1,>=0.13.2->ydata-profiling->pandas-profiling) (1.16.0)
# Downloading pandas_profiling-3.6.6-py2.py3-none-any.whl (324 kB)
# Downloading ydata_profiling-4.11.0-py2.py3-none-any.whl (390 kB)
# Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
# Downloading dacite-1.8.1-py3-none-any.whl (14 kB)
# Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Downloading numba-0.60.0-cp310-cp310-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 2.7/2.7 MB 39.1 MB/s eta 0:00:00
# Downloading numpy-2.0.2-cp310-cp310-win_amd64.whl (15.9 MB)
#    ---------------------------------------- 0.0/15.9 MB ? eta -:--:--
#    -------------------- ------------------- 8.1/15.9 MB 38.7 MB/s eta 0:00:01
#    ---------------------------------------- 15.9/15.9 MB 41.7 MB/s eta 0:00:00
# Downloading phik-0.12.4-cp310-cp310-win_amd64.whl (666 kB)
#    ---------------------------------------- 0.0/666.2 kB ? eta -:--:--
#    --------------------------------------- 666.2/666.2 kB 26.9 MB/s eta 0:00:00
# Downloading pydantic-2.9.2-py3-none-any.whl (434 kB)
# Downloading pydantic_core-2.23.4-cp310-none-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------------------- 1.9/1.9 MB 35.2 MB/s eta 0:00:00
# Downloading scipy-1.13.1-cp310-cp310-win_amd64.whl (46.2 MB)
#    ---------------------------------------- 0.0/46.2 MB ? eta -:--:--
#    ------- -------------------------------- 8.1/46.2 MB 42.1 MB/s eta 0:00:01
#    ----------------- ---------------------- 19.7/46.2 MB 49.6 MB/s eta 0:00:01
#    --------------------------- ------------ 31.7/46.2 MB 51.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 40.9/46.2 MB 53.0 MB/s eta 0:00:01
#    ---------------------------------------- 46.2/46.2 MB 49.8 MB/s eta 0:00:00
# Downloading typeguard-4.3.0-py3-none-any.whl (35 kB)
# Downloading visions-0.7.6-py3-none-any.whl (104 kB)
# Downloading wordcloud-1.9.3-cp310-cp310-win_amd64.whl (299 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading llvmlite-0.43.0-cp310-cp310-win_amd64.whl (28.1 MB)
#    ---------------------------------------- 0.0/28.1 MB ? eta -:--:--
#    -------------- ------------------------- 10.2/28.1 MB 49.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 19.9/28.1 MB 48.4 MB/s eta 0:00:01
#    ---------------------------------------  28.0/28.1 MB 48.1 MB/s eta 0:00:01
#    ---------------------------------------- 28.1/28.1 MB 42.5 MB/s eta 0:00:00
# Downloading pywavelets-1.7.0-cp310-cp310-win_amd64.whl (4.3 MB)
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    ---------------------------------------- 4.3/4.3 MB 42.4 MB/s eta 0:00:00
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py): started
#   Building wheel for htmlmin (setup.py): finished with status 'done'
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27091 sha256=f5e0ed2a96e1e68be55b35be65b7de1996601af93d43152b892f75afd17e35e6
#   Stored in directory: c:\users\ramon\appdata\local\pip\cache\wheels\dd\91\29\a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# Successfully built htmlmin
# Installing collected packages: htmlmin, typeguard, pydantic-core, numpy, multimethod, llvmlite, dacite, annotated-types, scipy, PyWavelets, pydantic, numba, visions, imagehash, wordcloud, phik, ydata-profiling, pandas-profiling
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.2
#     Uninstalling numpy-2.1.2:
#       Successfully uninstalled numpy-2.1.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.14.1
#     Uninstalling scipy-1.14.1:
#       Successfully uninstalled scipy-1.14.1
# Successfully installed PyWavelets-1.7.0 annotated-types-0.7.0 dacite-1.8.1 htmlmin-0.1.12 imagehash-4.3.1 llvmlite-0.43.0 multimethod-1.12 numba-0.60.0 numpy-2.0.2 pandas-profiling-3.6.6 phik-0.12.4 pydantic-2.9.2 pydantic-core-2.23.4 scipy-1.13.1 typeguard-4.3.0 visions-0.7.6 wordcloud-1.9.3 ydata-profiling-4.11.0
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\RAMON\miniconda3\envs\practica0\Lib\site-packages\~umpy'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\RAMON\AppData\Local\Temp\pip-uninstall-a8dvz4le'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\RAMON\miniconda3\envs\practica0\Lib\site-packages\scipy\_lib\~uarray'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\RAMON\miniconda3\envs\practica0\Lib\site-packages\scipy\~luster'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\RAMON\miniconda3\envs\practica0\Lib\site-packages\scipy\~ft'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\RAMON\miniconda3\envs\practica0\Lib\site-packages\scipy\~ftpack'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\RAMON\miniconda3\envs\practica0\Lib\site-packages\scipy\~ntegrate'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\RAMON\miniconda3\envs\practica0\Lib\site-packages\scipy\~nterpolate'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\RAMON\miniconda3\envs\practica0\Lib\site-packages\scipy\~inalg'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\RAMON\miniconda3\envs\practica0\Lib\site-packages\scipy\~dimage'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\RAMON\miniconda3\envs\practica0\Lib\site-packages\scipy\~ptimize'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\RAMON\miniconda3\envs\practica0\Lib\site-packages\scipy\~ignal'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\RAMON\miniconda3\envs\practica0\Lib\site-packages\scipy\~parse'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\RAMON\miniconda3\envs\practica0\Lib\site-packages\scipy\~patial'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\RAMON\miniconda3\envs\practica0\Lib\site-packages\scipy\~pecial'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\RAMON\miniconda3\envs\practica0\Lib\site-packages\scipy\~tats'.
#   You can safely remove it manually.
# ---------------------------------------------------------------------------
# PydanticImportError                       Traceback (most recent call last)
# Cell In[10], line 3
#       1 get_ipython().system('pip install pandas-profiling')
#       2 import pandas as pd
# ----> 3 from pandas_profiling import ProfileReport
#       5 profile = ProfileReport(loan, title='Informe de Análisis Exploratorio de Datos', explorative=True)
#       6 profile.to_widgets()
#
# File ~\miniconda3\envs\practica0\lib\site-packages\pandas_profiling\__init__.py:8
#       1 """Main module of pandas-profiling.
#       2
#       3 .. include:: ../../README.md
#       4 """
#       6 from warnings import warn
# ----> 8 from pandas_profiling.compare_reports import compare
#       9 from pandas_profiling.controller import pandas_decorator
#      10 from pandas_profiling.profile_report import ProfileReport
#
# File ~\miniconda3\envs\practica0\lib\site-packages\pandas_profiling\compare_reports.py:6
#       2 from typing import Any, List, Optional, Tuple, Union
#       4 import pandas as pd
# ----> 6 from pandas_profiling.config import Correlation, Settings
#       7 from pandas_profiling.model.alerts import Alert
#       8 from pandas_profiling.profile_report import ProfileReport
#
# File ~\miniconda3\envs\practica0\lib\site-packages\pandas_profiling\config.py:7
#       4 from typing import Any, Dict, List, Optional, Tuple, Union
#       6 import yaml
# ----> 7 from pydantic import BaseModel, BaseSettings, Field, PrivateAttr
#      10 def _merge_dictionaries(dict1: dict, dict2: dict) -> dict:
#      11     """
#      12     Recursive merge dictionaries.
#      13
#    (...)
#      16     :return: Merged dictionary
#      17     """
#
# File ~\miniconda3\envs\practica0\lib\site-packages\pydantic\__init__.py:402, in __getattr__(attr_name)
#     400 dynamic_attr = _dynamic_imports.get(attr_name)
#     401 if dynamic_attr is None:
# --> 402     return _getattr_migration(attr_name)
#     404 package, module_name = dynamic_attr
#     406 if module_name == '__module__':
#
# File ~\miniconda3\envs\practica0\lib\site-packages\pydantic\_migration.py:296, in getattr_migration.<locals>.wrapper(name)
#     294     return import_string(REDIRECT_TO_V1[import_path])
#     295 if import_path == 'pydantic:BaseSettings':
# --> 296     raise PydanticImportError(
#     297         '`BaseSettings` has been moved to the `pydantic-settings` package. '
#     298         f'See https://docs.pydantic.dev/{version_short()}/migration/#basesettings-has-moved-to-pydantic-settings '
#     299         'for more details.'
#     300     )
#     301 if import_path in REMOVED_IN_V2:
#     302     raise PydanticImportError(f'`{import_path}` has been removed in V2.')
#
# PydanticImportError: `BaseSettings` has been moved to the `pydantic-settings` package. See https://docs.pydantic.dev/2.9/migration/#basesettings-has-moved-to-pydantic-settings for more details.
#
# For further information visit https://errors.pydantic.dev/2.9/u/import-error
